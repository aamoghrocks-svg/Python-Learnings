# %% [markdown]
# <a href="https://colab.research.google.com/github/aamoghrocks-svg/Python-Learnings/blob/master/Love%20Calc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# def calculate_love_score(name1,name2):
#     for letter1 in name1:
#         print(letter1)
#         if letter1 in ["t","r","u","e"]:
#             match += count(letter1)

#     # for letter2 in name2:
#     #     print(letter2)

# match = 0
# calculate_love_score(name1="Angela Yu", name2="Jack Bauer")




def calculate_love_score(name1, name2):

    combined_names = (name1 + name2).lower()

    t = combined_names.count("t")
    r = combined_names.count("r")
    u = combined_names.count("u")
    e = combined_names.count("e")

    true = t + r + u + e

    print(f"True score: {true}")

    l = combined_names.count("l")
    o = combined_names.count("o")
    v = combined_names.count("v")
    e = combined_names.count("e")
    love = l + o + v + e
    print(f"Love score: {love}")

#     for word1 in ['t', 'r', 'u', 'e']:
#         score1 = 0
#         score1 += combined_names.count(word1)
#         print(combined_names)
#         return score1

#     for word2 in ['l', 'o', 'v', 'e']:
#         score2 = 0
#         score2 += combined_names.count(word2)
#         print(score2)

#         return score2

# match = 0
match = calculate_love_score(name1="Angela Yu", name2="Jack Bauer")

# You can print the final score if needed
#print(f"Love score: {match}")
# print(score1)
# print(score2)
# Out:
# True score: 5
# Love score: 3
